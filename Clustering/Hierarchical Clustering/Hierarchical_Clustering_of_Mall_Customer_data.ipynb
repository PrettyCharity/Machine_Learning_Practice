# %%
#@title Preparing the data
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("ticks")

# Loading the data
df = pd.read_csv('Data.csv')
X = df.iloc[:, 1:]
# Handling categorical data
X = pd.get_dummies(X).values

# %%
#@title Using the Dendrogram to find the optimal number of clusters
import scipy.cluster.hierarchy as sch
plt.figure(figsize = (16, 10))
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward', 
                                        metric = 'euclidean'))
plt.title('Dendrogram', size = 24)
plt.xlabel('Customers', size = 18)
plt.ylabel('Euclidean distances', size = 18)
plt.show()

# %%
#@title Training Hierarchical Clustering model on the dataset
from sklearn.cluster import AgglomerativeClustering
model = AgglomerativeClustering(n_clusters = None, affinity= 'euclidean', 
                                linkage = 'ward', compute_full_tree=True, 
                                distance_threshold=200)
y_pred = model.fit_predict(X)

# %%
#@title Visualizing the clusters
plt.figure(figsize = (10, 6))
sns.scatterplot(x = X[:, 1], y = X[:, 2], c = y_pred, cmap = 'rainbow')
plt.title('Clusters of Customers', size = 18)
plt.xlabel('Annual Income (k$)', size = 14)
plt.ylabel('Spending Score (1-100)', size = 14)
plt.show()
